# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('file.csv')
df
# Out:
#    label                                               text
# 1    ham                    Hey are we still meeting today?
# 2   spam          WIN a brand new car! Click this link now!
# 3    ham               Don't forget to bring your notebook.
# 4   spam    Congratulations! You have won $5000. Claim now!
# 5    ham                       I'll call you in 10 minutes.
# 6   spam        Free entry in a contest. Text WIN to 90099.
# 7    ham                    Can you send me the assignment?
# 8   spam            Get cheap loans now with zero interest!
# 9    ham                         Are you coming for dinner?
# 10  spam    You have been selected for a prize. Click here!
# 11   ham                    Let's meet at the cafe at 6 pm.
# 12  spam  Lowest price medicines available online. Order...
# 13   ham                             I reached home safely.
# 14  spam         Claim your reward now. Limited time offer!
# 15   ham                           Please check your email.

# %%
print(df.duplicated(subset='text').sum())
print(df.isnull().sum())
# Out:
# 0
# label    0
# text     0
# dtype: int64

# %%
df.drop_duplicates(subset='text', inplace=True)
df.reset_index(drop=True, inplace=True)
print(df.duplicated(subset='text').sum())
# Out:
# 0

# %%
import re

def clean_email(text):
    text = str(text).lower()                    # lowercase
    text = re.sub(r"http\S+|www.\S+", "", text) # remove links
    text = re.sub(r"\S+@\S+", "", text)         # remove email addresses
    text = re.sub(r"[^a-z\s]", "", text)        # keep only alphabets
    text = re.sub(r"\s+", " ", text).strip()    # remove extra spaces
    return text

df["text"] = df["text"].apply(clean_email)

# Correct column name: 'label' (not 'Label')
df = df[['text', 'label']]

df
# Out:
#                                                  text label
# 0                      hey are we still meeting today   ham
# 1             win a brand new car click this link now  spam
# 2                  dont forget to bring your notebook   ham
# 3              congratulations you have won claim now  spam
# 4                             ill call you in minutes   ham
# 5                 free entry in a contest text win to  spam
# 6                      can you send me the assignment   ham
# 7              get cheap loans now with zero interest  spam
# 8                           are you coming for dinner   ham
# 9       you have been selected for a prize click here  spam
# 10                        lets meet at the cafe at pm   ham
# 11  lowest price medicines available online order now  spam
# 12                              i reached home safely   ham
# 13           claim your reward now limited time offer  spam
# 14                            please check your email   ham

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.3.4)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.model_selection import train_test_split

# Split first
X_train, X_test, y_train, y_test = train_test_split(df["text"], df["label"], test_size=0.2, random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english', max_features=5000)
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)
y_train = y_train.map({'ham': 0, 'spam': 1})
y_test = y_test.map({'ham': 0, 'spam': 1})

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

model = LogisticRegression(max_iter=1000)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.3333333333333333
#
# Confusion Matrix:
#  [[1 0]
#  [2 0]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50         1
#            1       0.00      0.00      0.00         2
#
#     accuracy                           0.33         3
#    macro avg       0.17      0.50      0.25         3
# weighted avg       0.11      0.33      0.17         3
# C:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\ADMIN\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
